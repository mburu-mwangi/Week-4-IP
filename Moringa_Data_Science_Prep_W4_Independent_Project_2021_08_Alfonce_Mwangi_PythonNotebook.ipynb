# %% [markdown]
# <a href="https://colab.research.google.com/github/mburu-mwangi/Week-4-IP/blob/main/Moringa_Data_Science_Prep_W4_Independent_Project_2021_08_Alfonce_Mwangi_PythonNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Week 4 IP requirements as follows:

# %% [markdown]
# 1. Identify the most popular hour of the day for picking up a shared electric car (Bluecar) in the city of Paris over the month of April 2018.
#
# 2. What is the most popular hour for returning cars?
#
# 3. What station is the most popular?
# Overall?
#
# 4. At the most popular picking hour?
#
# 5. What postal code is the most popular for picking up Blue cars?
#
# Does the most popular station belong to that postal code?
#
# Overall?
#
# At the most popular picking hour?
#
# 6. Do the results change if you consider Utilib and Utilib 1.4 instead of Blue cars?

# %%
# importing pandas library
import pandas as pd
# improting numpy library
import numpy as np

# %% [markdown]
# ## 1. Loading the data

# %%
df_autolib=pd.read_csv('/content/Autolib_dataset (2).csv')
df_autolib.head()
# Out:
#                               Address  Cars  Bluecar counter  ...  day  hour  minute
# 0                 2 Avenue de Suffren     0                0  ...    8    11      43
# 1           145 Rue Raymond Losserand     6                6  ...    6     7      24
# 2    2 Avenue John Fitzgerald Kennedy     3                3  ...    3    20      14
# 3              51 Rue Eug̬ne Oudin̩     3                3  ...    4     4      37
# 4  6 avenue de la Porte de Champerret     3                3  ...    8    17      23
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 2. Data Cleaning

# %%
#checking for duplicates
df_autolib.duplicated().sum()

# There are no duplicates in the data
# Out:
# 0

# %%
# checking for missing data
df_autolib.isnull().sum()
# Out:
# Address                   0
# Cars                      0
# Bluecar counter           0
# Utilib counter            0
# Utilib 1.4 counter        0
# Charge Slots              0
# Charging Status           0
# City                      0
# Displayed comment      4889
# ID                        0
# Kind                      0
# Geo point                 0
# Postal code               0
# Public name               0
# Rental status             0
# Scheduled at           4953
# Slots                     0
# Station type              0
# Status                    0
# Subscription status       0
# year                      0
# month                     0
# day                       0
# hour                      0
# minute                    0
# dtype: int64

# %%
# getting the data info
df_autolib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   Displayed comment    111 non-null    object
#  9   ID                   5000 non-null   object
#  10  Kind                 5000 non-null   object
#  11  Geo point            5000 non-null   object
#  12  Postal code          5000 non-null   int64
#  13  Public name          5000 non-null   object
#  14  Rental status        5000 non-null   object
# ...

# %%
# creating the column 'date' and converting the type to datetime 
# as well as merging the columns: 'month','day','year','hour','minute'
df_autolib['date']=pd.to_datetime(df_autolib[['month','day','year','hour', 'minute']])

# %%
df_autolib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   Displayed comment    111 non-null    object
#  9   ID                   5000 non-null   object
#  10  Kind                 5000 non-null   object
#  11  Geo point            5000 non-null   object
#  12  Postal code          5000 non-null   int64
#  13  Public name          5000 non-null   object
#  14  Rental status        5000 non-null   object
# ...

# %%
df_autolib.head()
# Out:
#                               Address  Cars  ...  minute                date
# 0                 2 Avenue de Suffren     0  ...      43 2018-04-08 11:43:00
# 1           145 Rue Raymond Losserand     6  ...      24 2018-04-06 07:24:00
# 2    2 Avenue John Fitzgerald Kennedy     3  ...      14 2018-04-03 20:14:00
# 3              51 Rue Eug̬ne Oudin̩     3  ...      37 2018-04-04 04:37:00
# 4  6 avenue de la Porte de Champerret     3  ...      23 2018-04-08 17:23:00
#
# [5 rows x 26 columns]

# %%
# Looking for un operational stations
df_autolib_operational =df_autolib[df_autolib['Rental status']== 'operational']
# Displaying them
df_autolib_operational
# Out:
#                                  Address  Cars  ...  minute                date
# 0                    2 Avenue de Suffren     0  ...      43 2018-04-08 11:43:00
# 1              145 Rue Raymond Losserand     6  ...      24 2018-04-06 07:24:00
# 2       2 Avenue John Fitzgerald Kennedy     3  ...      14 2018-04-03 20:14:00
# 3                 51 Rue Eug̬ne Oudin̩     3  ...      37 2018-04-04 04:37:00
# 4     6 avenue de la Porte de Champerret     3  ...      23 2018-04-08 17:23:00
# ...                                  ...   ...  ...     ...                 ...
# 4995                 8 avenue M̩nelotte     2  ...      26 2018-04-06 11:26:00
# 4996                   37 rue de Dantzig     4  ...      56 2018-04-04 16:56:00
# 4997                      142 rue du Bac     1  ...       1 2018-04-01 07:01:00
# 4998         2 avenue du Val de Fontenay     2  ...      27 2018-04-04 17:27:00
# 4999                 5 Rue Henry Brisson     4  ...       2 2018-04-08 10:02:00
#
# ...

# %% [markdown]
# ## 3. Analysis

# %%
# checking for the most popular hour for picking the bluecar

df_day=df_autolib_operational[df_autolib_operational['hour']<19]
df_day['hour'].mode()
# Out:
# 0    6
# dtype: int64

# %%
# selecting the most popular station
df_autolib_operational['ID'].value_counts()[df_autolib_operational['ID'].value_counts() == df_autolib_operational['ID'].value_counts().max()]
# Out:
# paris-portedemontrouge-8    13
# Name: ID, dtype: int64

# %%
# selecting the most common postal code
print(df_autolib_operational['Postal code'].mode())
# Out:
# 0    75015
# dtype: int64

# %%
# most common picking hour
print(df_autolib_operational['hour'].mode())
# Out:
# 0    21
# dtype: int64
